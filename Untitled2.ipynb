# %%
text = "i love india"

# %%
text.split()
# Out:
# ['i', 'love', 'india']

# %%
for word in text.split():
    print(word[::-1])
# Out:
# i
# evol
# aidni

# %%
print(" ".join(word[::-1]for word in text.split()))
# Out:
# i evol aidni

# %%
text.split()
# Out:
# ['i', 'love', 'india']

# %%
word = text.split()

# %%
print(word[::-1])
# Out:
# ['india', 'love', 'i']

# %%
print(" ".join(word))
# Out:
# i love india

# %%
a=2

# %%
b=3

# %%
c=5
