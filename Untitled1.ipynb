# %%
text = 'i love India'

# %%
text.split()
# Out:
# ['i', 'love', 'India']

# %%
 for word in text.split():
  print(word[::-1])
# Out:
# i
# evol
# aidnI

# %%
print(" ".join(word[::-1]for word in text.split()))
# Out:
# i evol aidnI
